# %%
# !wget -O pose_landmarker.task -q https://storage.googleapis.com/mediapipe-models/pose_landmarker/pose_landmarker_heavy/float16/1/pose_landmarker_heavy.task

# %%
import cv2
import mediapipe as mp
import time

mp_pose = mp.solutions.pose
mp_drawing = mp.solutions.drawing_utils

# %%
# TODO: check if OpenCV or MediaPipe/Tensorflow doesn't provide already
def calc_distance(landmark1, landmark2):
    x = (landmark1.x - landmark2.x)**2
    y = (landmark1.y - landmark2.y)**2
    z = (landmark1.z - landmark2.z)**2
    
    return (x + y + z)**(1/2)

# %%
path = 'data/lat_pulldown1.mp4'
cap = cv2.VideoCapture(path)

if (cap.isOpened()== False): 
  print("Error opening video stream or file")

# TODO: In real time figure out which side is closer to the camera and use the appropriate wrist, elbow
# TODO: Running average of the wrist-elbow distance?
WRIST = mp_pose.PoseLandmark.RIGHT_WRIST
ELBOW = mp_pose.PoseLandmark.RIGHT_ELBOW
wrist_landmarks = []

with mp_pose.Pose() as pose:
    while(cap.isOpened()):
        ret, frame = cap.read()

        if ret:
            image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            image.flags.writeable = False

            results = pose.process(image)
            wrist_landmarks.append(results.pose_world_landmarks.landmark[WRIST])

            image.flags.writeable = True
            image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
            
            mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS)

            cv2.imshow(path, image)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        else:
            break

cap.release()
cv2.destroyAllWindows()

# %%
# TODO: Plot in 3d, calculate the rep speed, compare accuracy.
wrist_landmarks
# Out:
# [x: 0.08321528136730194
#  y: -0.948345422744751
#  z: -0.08589436858892441
#  visibility: 0.9814456105232239,
#  x: 0.10080721974372864
#  y: -0.9415350556373596
#  z: -0.10985613614320755
#  visibility: 0.9818453192710876,
#  x: 0.10503260791301727
#  y: -0.9367219805717468
#  z: -0.11482609808444977
#  visibility: 0.9823163747787476,
#  x: 0.10517196357250214
#  y: -0.9346667528152466
#  z: -0.12538406252861023
#  visibility: 0.9826623201370239,
#  x: 0.10953428596258163
#  y: -0.9451706409454346
#  z: -0.14142420887947083
#  visibility: 0.9828631281852722,
#  x: 0.11589116603136063
#  y: -0.9515793323516846
#  z: -0.14950278401374817
#  visibility: 0.9831752777099609,
#  x: 0.1166052296757698
#  y: -0.9522861242294312
#  z: -0.14941075444221497
#  visibility: 0.9833047389984131,
#  x: 0.11770462244749069
#  y: -0.9532055854797363
#  z: -0.15063320100307465
#  visibility: 0.9833962321281433,
#  x: 0.11690052598714828
#  y: -0.9509552121162415
#  z: -0.149147629737854
# ...
